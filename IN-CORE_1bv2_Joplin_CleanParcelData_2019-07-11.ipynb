# %% [markdown]
# # Clean Parcel Data
# Step required to make the Probabilistic Housing Unit Allocation work.
#
# County Parcel Data needs to be combined with Tax Accessor Data, Census Block, Census Place and PUMA data.
#
# Initial Parcel Data provides Parcel ID and zoning infomration information but does not identify the Census Geography.
# The Census Geogrpahy will help to check to make sure that all buildings within the parcel boundaries and the Census Place Boundary are matched. If there are parcels in the Census Place boundary that should have buildings but do not this information may help to prioritize efforts to update the Building Inventory.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pysal as ps
import math as math
import numpy as np
import geopandas as gpd
import pandas as pd
import shapely
import descartes
import folium as fm # folium has more dynamic maps - but requires internet connection
import os # For saving output to path
# Out:
# C:\Users\nathanael99\AppData\Local\Continuum\anaconda3\envs\pyincore20190618\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %%
# Display versions being used - important information for replication
import sys
print("Python Version     ", sys.version)
print("pysal version:     ", ps.__version__)
print("numpy version:     ", np.__version__)
print("geopandas version: ", gpd.__version__)
print("pandas version:    ", pd.__version__)
print("shapely version:   ", shapely.__version__)
# print("descartes version:   ", descartes.__version__)  1.1.0
print("folium version:    ", fm.__version__)
# print("os version:    ", os.__version__)
# Out:
# Python Version      3.7.3 (default, Apr 24 2019, 15:29:51) [MSC v.1915 64 bit (AMD64)]
# pysal version:      2.0.0
# numpy version:      1.16.4
# geopandas version:  0.5.0
# pandas version:     0.24.2
# shapely version:    1.6.4.post1
# folium version:     0.9.1

# %%
# Store Program Name for output files to have the same name
programname = "IN-CORE_1bv2_Joplin_CleanParcelData_2019-07-11"
# Make directory to save output
if not os.path.exists(programname):
    os.mkdir(programname)

# %% [markdown]
# ## Read in Parcel Data
# Jasper County MO (FIPS 29097) provided Parcel Data for the entire county.
# At the time of this program Newton County MO (FIPS 29145) was not provided.

# %%
parceldata_shp = '../../SourceData/joplin_footprints/confuence_joplin_datasets/jcmo_shapes/parcels.shp'
parceldata_gdf = gpd.read_file(parceldata_shp)
parceldata_gdf.head()
# Out:
#                  PIN  Graphic_Ac  Legal_Ac           Address Notes Zoning  \
# 0  13401800000014001     23.6552   23.6552  0  COUNTY RD 100  None   None
# 1  20300810003013001      0.9522    0.9522    4575 E 13TH ST  None   None
# 2  16502110001010001      0.4072    0.4200      0  COUNTY RD  None   None
# 3  17101200000029002      3.0026    3.0303  29146  HUNTER RD  None   None
# 4  11703500000012000     26.8550   26.7800     677  JEWEL RD  None   None
#
#                            Own_Name  \
# 0  BRINSON, FRANKLIN L & CHRYSTAL G
# 1                        MACC GROUP
# 2              SELFRIDGE, STEPHEN W
# 3                     WALD, DAVID L
# 4                  MSJR CORPORATION
#
#                                        Own_Addres   SHAPE_Leng    SHAPE_Area  \
# 0       5113 E RICHLAND AVE ;CHILLICOTHE;IL;61523  4202.319148  1.030421e+06
# 1               5293 E BALTIC LN ;JOPLIN;MO;64801   819.860123  4.147823e+04
# 2                  26164  FIR RD ;JOPLIN;MO;64801   711.235010  1.773705e+04
# 3        29146  HUNTER RD ;CARL JUNCTION;MO;64834  1453.963248  1.307927e+05
# 4  7437  LAWRENCE COUNTY AVE ;LA RUSSELL;MO;64848  4591.195160  1.169805e+06
#
#                                             geometry
# 0  POLYGON ((2865172.3909375 355416.8737500012, 2...
# 1  POLYGON ((2803423.38625 331477.0365625024, 280...
# 2  POLYGON ((2779427.922812503 355518.2256250047,...
# 3  POLYGON ((2764652.6171875 364145.4900000021, 2...
# 4  POLYGON ((2915297.200625 371798.0109375, 29152...

# %%
parceldata_gdf.crs
# Out:
# {'proj': 'tmerc',
#  'lat_0': 36.16666666666666,
#  'lon_0': -94.5,
#  'k': 0.9999411764705882,
#  'x_0': 849999.9999999999,
#  'y_0': 0,
#  'datum': 'NAD83',
#  'units': 'us-ft',
#  'no_defs': True}

# %%
# Get error in to_crs that can be fixed with the following command
parceldata_gdf = parceldata_gdf[parceldata_gdf.geometry.notnull()]
# Parcel Data projected to have lat Lon for building rep point
latlong_crs = {'init':'epsg:4326'}
parceldata_gdf = parceldata_gdf.to_crs(latlong_crs)
parceldata_gdf.head()
# Out:
#                  PIN  Graphic_Ac  Legal_Ac           Address Notes Zoning  \
# 0  13401800000014001     23.6552   23.6552  0  COUNTY RD 100  None   None
# 1  20300810003013001      0.9522    0.9522    4575 E 13TH ST  None   None
# 2  16502110001010001      0.4072    0.4200      0  COUNTY RD  None   None
# 3  17101200000029002      3.0026    3.0303  29146  HUNTER RD  None   None
# 4  11703500000012000     26.8550   26.7800     677  JEWEL RD  None   None
#
#                            Own_Name  \
# 0  BRINSON, FRANKLIN L & CHRYSTAL G
# 1                        MACC GROUP
# 2              SELFRIDGE, STEPHEN W
# 3                     WALD, DAVID L
# 4                  MSJR CORPORATION
#
#                                        Own_Addres   SHAPE_Leng    SHAPE_Area  \
# 0       5113 E RICHLAND AVE ;CHILLICOTHE;IL;61523  4202.319148  1.030421e+06
# 1               5293 E BALTIC LN ;JOPLIN;MO;64801   819.860123  4.147823e+04
# 2                  26164  FIR RD ;JOPLIN;MO;64801   711.235010  1.773705e+04
# 3        29146  HUNTER RD ;CARL JUNCTION;MO;64834  1453.963248  1.307927e+05
# 4  7437  LAWRENCE COUNTY AVE ;LA RUSSELL;MO;64848  4591.195160  1.169805e+06
#
#                                             geometry
# 0  POLYGON ((-94.23765986801661 37.14264461623644...
# 1  POLYGON ((-94.44955759890132 37.07717068019272...
# 2  POLYGON ((-94.53184037806825 37.14320902194232...
# 3  POLYGON ((-94.58255904726742 37.16688013485778...
# 4  POLYGON ((-94.06543302536771 37.18713022533776...

# %%
# Add Representative Point
parceldata_gdf.loc[parceldata_gdf.index, 'rppnt4326'] = parceldata_gdf['geometry'].representative_point()
parceldata_gdf['rppnt4326'].label = "Representative Point EPSG 4326 (WKT)"
parceldata_gdf['rppnt4326'].notes = "Internal Point within parcel poly EPSG 4326"

# Add Column that Duplicates Polygon Geometry - allows for swithcing between point and polygon geometries for spatial join
parceldata_gdf.loc[parceldata_gdf.index, 'prcl4326'] = parceldata_gdf['geometry']
parceldata_gdf['prcl4326'].label = "Parcel Polygon EPSG 4326 (WKT)"
parceldata_gdf['prcl4326'].notes = "Polygon Shape Points for Parcel Polygon EPSG 4326"

# %% [markdown]
# ## Does the Parcel Data have a Unique ID

# %%
# Count the number of Unique Values
parceldata_gdf[['PIN']].describe()
# Out:
#            PIN
# count    57302
# unique   57235
# top     ISLAND
# freq        14

# %%
# Are there any missing values for the unique id?
parceldata_gdf.loc[parceldata_gdf['PIN'].isnull()]
# Out:
#         PIN  Graphic_Ac  Legal_Ac Address Notes Zoning Own_Name Own_Addres  \
# 50277  None         0.0       0.0    None  None   None     None       None
# 50278  None         0.0       0.0    None  None   None     None       None
#
#         SHAPE_Leng    SHAPE_Area  \
# 50277  6820.817115  2.290892e+06
# 50278  1819.195223  7.436522e+04
#
#                                                 geometry  \
# 50277  POLYGON ((-94.42260311421195 37.08057721265357...
# 50278  POLYGON ((-94.42242013382311 37.08106111848689...
#
#                                           rppnt4326  \
# 50277  POINT (-94.41848334555092 37.08130172885706)
# 50278   POINT (-94.42213046784147 37.0818570045905)
#
#                                                 prcl4326
# 50277  POLYGON ((-94.42260311421195 37.08057721265357...
# 50278  POLYGON ((-94.42242013382311 37.08106111848689...

# %%
# List duplicates for the Unique ID
pd.crosstab(index=parceldata_gdf.duplicated(subset=['PIN']), columns="count", margins=True, margins_name="Total")
#parceldata_gdf.loc[parceldata_gdf.duplicated(subset=['PIN'])]
# Out:
# col_0  count  Total
# row_0
# False  57236  57236
# True      68     68
# Total  57304  57304

# %% [markdown]
# It appears that PIN is a mix of numbers and strings. With 57,302 values and 57,235 unique values. There are 68 duplicates and 2 missing values.

# %%
# Collapse Parcels By Parcel ID
parceldata_gdf_parcelcount = parceldata_gdf[['PIN']]
parceldata_gdf_parcelcount['parcel_count'] = 1
parceldata_gdf_parcelcount_sum = parceldata_gdf_parcelcount.groupby(['PIN']).sum()
parceldata_gdf_parcelcount_sum['parcel_count'].describe()
# Out:
# C:\Users\nathanael99\AppData\Local\Continuum\anaconda3\envs\pyincore20190618\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# count    57235.000000
# mean         1.001171
# std          0.084112
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         14.000000
# Name: parcel_count, dtype: float64

# %%
parceldata_gdf_parcelcount_sum.loc[parceldata_gdf_parcelcount_sum['parcel_count']>1]
# Out:
#                           parcel_count
# PIN
# 07601400000001000                    2
# 07601400000001001                    2
# 07802800000004005                    2
# 08501520011014000                    2
# 08803400000009008                    3
# 08902900000011023                    2
# 08903140009019000                    2
# 09703500000054000                    2
# 13402000000020000                    2
# 14200330025010000                    2
# 14401700000023000                    3
# 15300740008011007                    2
# 15501510002001051                    2
# 15802800000006000                    2
# 15902900000032000                    2
# 16101220001003000                    2
# 16602420002005000                    2
# 16602440004007000                    2
# 16702520006049002                    2
# 16702520006050000                    2
# 16702520006051000                    2
# 16703610001088000                    2
# 19100230028001000                    2
# 19200422001004001                    2
# 19601320007006000                    2
# 20200900000001002                    2
# CONFLICT                             9
# EMPIRE                               3
# EMPIRE DISTRICT ELECTRIC             7
# ISLAND                              14
# UNK                                 11

# %%
parceldata_gdf[['PIN','geometry']].loc[parceldata_gdf['PIN']== '14401700000023000']
# Out:
#                      PIN                                           geometry
# 42758  14401700000023000  POLYGON ((-94.34279600734241 37.1547468787871,...
# 56967  14401700000023000  (POLYGON ((-94.3375649304737 37.14519332473801...
# 56968  14401700000023000  POLYGON ((-94.34336092343381 37.15221214624182...

# %% [markdown]
# ### For the duplicate Parcels Errors in Geometry
# It looks like the duplicate parcels do not have the same geographies. Parcel PIN 14401700000023000 has 3 polygons, and one of the polygons is a multipolygon.
# #### Use Dissolve to combine Polygons by PIN

# %%
parceldata_gdf_dissolve = parceldata_gdf[['PIN','SHAPE_Area']]
parceldata_gdf_dissolve = parceldata_gdf.dissolve(by=parceldata_gdf['PIN'])
parceldata_gdf_dissolve.loc[parceldata_gdf_dissolve['PIN']== '14401700000023000']
# Out:
#                                                             geometry  \
# PIN
# 14401700000023000  (POLYGON ((-94.34279600734241 37.1547468787871...
#
#                                  PIN  Graphic_Ac  Legal_Ac  \
# PIN
# 14401700000023000  14401700000023000     209.741   209.741
#
#                                                  Address Notes Zoning  \
# PIN
# 14401700000023000  15823  15879,15895,15889,15915 FIR RD  None   None
#
#                                  Own_Name                          Own_Addres  \
# PIN
# 14401700000023000  BLANKENSHIP, PHILLIP W  2012 S QUEST LN ;CARTHAGE;MO;64836
#
#                      SHAPE_Leng    SHAPE_Area  \
# PIN
# 14401700000023000  11372.485293  3.940629e+06
#
#                                                       rppnt4326  \
# PIN
# 14401700000023000  POINT (-94.34191422085354 37.15072198711439)
#
#                                                             prcl4326
# PIN
# 14401700000023000  POLYGON ((-94.34279600734241 37.1547468787871,...

# %%
pd.crosstab(parceldata_gdf_dissolve['Zoning'], 'count',
            margins=True, margins_name="Total")
# Out:
# col_0     count  Total
# Zoning
# C1          338    338
# C1-PD        50     50
# C2          303    303
# C2-PD        28     28
# C3          432    432
# C3-PD        26     26
# CO          164    164
# CO-PD        39     39
# M1            7      7
# M1-PD        77     77
# M2          829    829
# M2-PD        15     15
# MULTIPLE      1      1
# N/A           8      8
# R1        11762  11762
# R1-PD        32     32
# R2         3012   3012
# R2-PD        68     68
# R3         1153   1153
# R3-PD       110    110
# R4           16     16
# Total     18470  18470

# %%
pd.crosstab(parceldata_gdf['Zoning'], 'count',
            margins=True, margins_name="Total")
# Out:
# col_0     count  Total
# Zoning
# C1          339    339
# C1-PD        50     50
# C2          303    303
# C2-PD        29     29
# C3          433    433
# C3-PD        26     26
# CO          164    164
# CO-PD        39     39
# M1            7      7
# M1-PD        77     77
# M2          839    839
# M2-PD        16     16
# MULTIPLE      1      1
# N/A           8      8
# R1        11776  11776
# R1-PD        32     32
# R2         3012   3012
# R2-PD        68     68
# R3         1153   1153
# R3-PD       110    110
# R4           16     16
# Total     18498  18498

# %%
# List duplicates for the Unique ID
pd.crosstab(index=parceldata_gdf_dissolve.duplicated(subset=['PIN']), columns="count", margins=True, margins_name="Total")
# Out:
# col_0  count  Total
# row_0
# False  57235  57235
# Total  57235  57235

# %% [markdown]
# ### It looks like the dissolve solves the duplicate parcel problem

# %%
# Save Work at this point - can not have multiple columns with WKT information when saving
wkt_columns = ['rppnt4326','prcl4326']
# remove wkt columns from list of cols
cols = [col for col in parceldata_gdf_dissolve if col not in wkt_columns]
savefile = sys.path[0]+"/"+programname+"/"+programname+".shp"
parceldata_gdf_dissolve[cols].to_file(savefile)

# %% [markdown]
# ## Clean Parcel Tax Data
# The parcel Shape File has the location of parcels with a Parcel ID.
#
# ### Residential and Commercial 2010 Tax Details
# Harvey Cuttler and the CSU Econ team collected data on Parcel Values.
#
# This data should merge with the Parcel ID.

# %%
parceldatavalues = '../../SourceData/joplin_footprints/confuence_joplin_datasets/Copy of 2010- 2012 Data Request Res  CommClass.xlsx'

# %%
parceldatavalues_2010res_df = pd.read_excel(parceldatavalues, sheet_name='2010 Res')
parceldatavalues_2010res_df.head()
# Out:
#    #  TAXYR             PARID                              OWN1    ADRNO  \
# 0  1   2010  1401700000002000        NEIDIGH, JOSEPH A & LISA L   5269.0
# 1  2   2010  1401700000003000            RILEY, DONALD W & ROSA   1564.0
# 2  3   2010  1401800000001000     POTTS, LOREN A JR & GEORGIA H  20912.0
# 3  4   2010  1401800000002000  BRUMMETT, BRANDON & KERI WHITTLE  20214.0
# 4  5   2010  1401800000002001                   REED, JEFFERY A  16032.0
#
#   ADRDIR        ADRSTR     CITYNAME STATECODE     ZIP1  ADRNO.1 ADRDIR.1  \
# 0    NaN         THORN       JASPER        MO  64755.0   5296.0      NaN
# 1      N        ARLENE       JOPLIN        MO  64801.0   5699.0      NaN
# 2    NaN  COUNTY RD 70       JASPER        MO  64755.0  20912.0      NaN
# 3    NaN  COUNTY RD 70       JASPER        MO  64755.0  20214.0      NaN
# 4    NaN  COUNTY RD 30  GOLDEN CITY        MO  64748.0   6445.0      NaN
#
#        ADRSTR.1 CLASS  YRBLT  CARD   ACRES   APRBLDG  APRLAND  APRTOT
# 0         THORN     R   1970     1  158.22   77070.0  63870.0  140940
# 1         THORN     R   1960     1  317.32   93500.0  87380.0  180880
# 2  COUNTY RD 70     R   1955     1  313.50   55610.0  79370.0  134980
# 3  COUNTY RD 70     R   1955     1  151.00   55920.0  53230.0  109150
# 4         THORN     R   2005     1   52.73  113400.0  21290.0  134690

# %%
parceldatavalues_2010comm_df = pd.read_excel(parceldatavalues, sheet_name='2010 Comm')
parceldatavalues_2010comm_df.head()
# Out:
#    #  TAXYR             PARID                            OWN1    ADRNO ADRDIR  \
# 0  1   2010  1401700000004000     PLEASANT VIEW CEMETERY ASSN      NaN    NaN
# 1  2   2010  2501500000002000  LEAMING, LEO DON & CATHERINE J  20654.0    NaN
# 2  3   2010  2702600000001000                   RUSH, ROCKY H   8378.0    NaN
# 3  4   2010  3501500000006000          DODSON, DAVID L & LOIS  15515.0    NaN
# 4  5   2010  3601330001004000          JONES, CARL J & BESSIE      NaN    NaN
#
#           ADRSTR     CITYNAME STATECODE     ZIP1  ...  ADRDIR.1  \
# 0            NaN  GOLDEN CITY        MO  64748.0  ...       NaN
# 1  COUNTY RD 100       JASPER        MO  64755.0  ...       NaN
# 2          SUMAC       JASPER        MO  64755.0  ...       NaN
# 3          THORN       JASPER        MO  64755.0  ...       NaN
# 4     PO BOX 236       JASPER        MO  64755.0  ...       NaN
#
#         ADRSTR.1   ACRES   APRBLDG  APRLAND  APRTOT  CARD  YRBLT  CLASS  \
# 0          THORN    2.48   10890.0    14880   25770     1   1900      E
# 1  COUNTY RD 100  326.06   82940.0    84990  167930     2   2006      A
# 2          SUMAC  140.32  112130.0    64840  176970     2   2006      C
# 3          THORN    4.16  102950.0     9400  112350     2   1987      C
# 4            4TH    1.12   24550.0     6480   31030     1   1980      C
#
#   STRUCTURE
# 0     620.0
# 1     354.0
# 2     342.0
# 3     342.0
# 4     336.0
#
# [5 rows x 21 columns]

# %%
residential_count = parceldatavalues_2010res_df['PARID'].count()
commericial_count =parceldatavalues_2010comm_df['PARID'].count()
expected_append_count = residential_count + commericial_count
print("The original data had ",residential_count," residential observations and ",commericial_count," commerical observations")
print("The combined data will have ",expected_append_count)
# Out:
# The original data had  40850  residential observations and  4608  commerical observations
# The combined data will have  45458

# %%
cols2010res = [col for col in parceldatavalues_2010res_df]
cols2010comm = [col for col in parceldatavalues_2010comm_df]
# Before appending recognize that the two files have different columns
list(set(cols2010comm) - set(cols2010res))
# Out:
# ['STRUCTURE']

# %%
# Add variable that identifies the source sheet from the Excel Sheet
parceldatavalues_2010res_df['taxsheet'] = '2010 Res'
parceldatavalues_2010comm_df['taxsheet'] = '2010 Comm'

# %%
# Append Commericial and Residential Data
parceldatavalues_2010_df = parceldatavalues_2010comm_df.append(parceldatavalues_2010res_df, sort=True)
parceldatavalues_2010_df['PARID'].count()
# Out:
# 45458

# %%
cols2010 = [col for col in parceldatavalues_2010_df]
cols2010
# Out:
# ['#',
#  'ACRES',
#  'ADRDIR',
#  'ADRDIR.1',
#  'ADRNO',
#  'ADRNO.1',
#  'ADRSTR',
#  'ADRSTR.1',
#  'APRBLDG',
#  'APRLAND',
#  'APRTOT',
#  'CARD',
#  'CITYNAME',
#  'CLASS',
#  'OWN1',
#  'PARID',
#  'STATECODE',
#  'STRUCTURE',
#  'TAXYR',
#  'YRBLT',
#  'ZIP1',
#  'taxsheet']

# %% [markdown]
# ### Check Append Worked as expected
# Compare values for Year Built and Structure. Structure was only on the Commercial Tax Sheet.

# %%
parceldatavalues_2010res_df['YRBLT'].describe()
# Out:
# count    40850.000000
# mean      1956.480245
# std         40.457549
# min          0.000000
# 25%       1925.000000
# 50%       1960.000000
# 75%       1991.000000
# max       2010.000000
# Name: YRBLT, dtype: float64

# %%
parceldatavalues_2010comm_df['YRBLT'].describe()
# Out:
# count    4608.000000
# mean     1960.659505
# std        93.207121
# min         0.000000
# 25%      1940.000000
# 50%      1975.000000
# 75%      1992.000000
# max      2010.000000
# Name: YRBLT, dtype: float64

# %%
parceldatavalues_2010_df['YRBLT'].describe()
# Out:
# count    45458.000000
# mean      1956.903889
# std         48.507236
# min          0.000000
# 25%       1925.000000
# 50%       1962.000000
# 75%       1992.000000
# max       2010.000000
# Name: YRBLT, dtype: float64

# %%
parceldatavalues_2010comm_df['STRUCTURE'].describe()
# Out:
# count    4604.000000
# mean      365.170721
# std        86.250923
# min       101.000000
# 25%       335.000000
# 50%       345.000000
# 75%       396.000000
# max       721.000000
# Name: STRUCTURE, dtype: float64

# %%
parceldatavalues_2010_df['STRUCTURE'].describe()
# Out:
# count    4604.000000
# mean      365.170721
# std        86.250923
# min       101.000000
# 25%       335.000000
# 50%       345.000000
# 75%       396.000000
# max       721.000000
# Name: STRUCTURE, dtype: float64

# %%
pd.crosstab(parceldatavalues_2010_df['CLASS'], parceldatavalues_2010_df['taxsheet'],
            margins=True, margins_name="Total")
# Out:
# taxsheet  2010 Comm  2010 Res  Total
# CLASS
# A                 7         7     14
# C              2927        70   2997
# E               242       182    424
# R               366     30578  30944
# Total          3542     30837  34379

# %% [markdown]
# ## Does the Parcel Tax Data have a Unique ID

# %%
# Count the number of Unique Values
parceldatavalues_2010_df[['PARID']].describe()
# Out:
#               PARID
# count  4.545800e+04
# mean   1.647011e+16
# std    3.786165e+15
# min    1.401700e+15
# 25%    1.450151e+16
# 50%    1.670253e+16
# 75%    1.920103e+16
# max    2.360140e+16

# %%
# Count the number of Unique Values
parceldatavalues_2010_df[['PARID']].nunique()
# Out:
# PARID    42146
# dtype: int64

# %%
# Are there any missing values for the unique id?
parceldatavalues_2010_df.loc[parceldatavalues_2010_df['PARID'].isnull()]
# Out:
# Empty DataFrame
# Columns: [#, ACRES, ADRDIR, ADRDIR.1, ADRNO, ADRNO.1, ADRSTR, ADRSTR.1, APRBLDG, APRLAND, APRTOT, CARD, CITYNAME, CLASS, OWN1, PARID, STATECODE, STRUCTURE, TAXYR, YRBLT, ZIP1, taxsheet]
# Index: []
#
# [0 rows x 22 columns]

# %%
# List duplicates for the Unique ID
pd.crosstab(index=parceldatavalues_2010_df.duplicated(subset=['PARID']), columns="count", margins=True, margins_name="Total")
#parceldata_gdf.loc[parceldata_gdf.duplicated(subset=['PIN'])]
# Out:
# col_0  count  Total
# row_0
# False  42146  42146
# True    3312   3312
# Total  45458  45458

# %% [markdown]
# It appears that PARID is only numeric. With 45,458 values and 42,146 unique values. There are 3,312 duplicates and no missing values.
#
# It is possible that for many of the duplicate values the individual appraisal values are the same.
#
# Let's collapse the data by PARID and see if the sum and count of the parcel values produces the same values.

# %%
# Collapse Parcels By Parcel ID
parceldatavalues_2010_df_parcelcount = parceldatavalues_2010_df[['PARID','APRBLDG','APRLAND','APRTOT']]
parceldatavalues_2010_df_parcelcount['parcel_count'] = 1
parceldatavalues_2010_df_parcelcount_sum = parceldatavalues_2010_df_parcelcount.groupby(['PARID']).sum()
parceldatavalues_2010_df_parcelcount_sum.head()
# Out:
# C:\Users\nathanael99\AppData\Local\Continuum\anaconda3\envs\pyincore20190618\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                   APRBLDG  APRLAND  APRTOT  parcel_count
# PARID
# 1401700000002000  77070.0  63870.0  140940             1
# 1401700000003000  93500.0  87380.0  180880             1
# 1401700000004000  10890.0  14880.0   25770             1
# 1401800000001000  55610.0  79370.0  134980             1
# 1401800000002000  55920.0  53230.0  109150             1

# %%
# Group by moves the unique id to the index - make a new variable for merge
parceldatavalues_2010_df_parcelcount_sum['parid'] = parceldatavalues_2010_df_parcelcount_sum.index
parceldatavalues_2010_df_parcelcount_sum.head()
# Out:
#                   APRBLDG  APRLAND  APRTOT  parcel_count             parid
# PARID
# 1401700000002000  77070.0  63870.0  140940             1  1401700000002000
# 1401700000003000  93500.0  87380.0  180880             1  1401700000003000
# 1401700000004000  10890.0  14880.0   25770             1  1401700000004000
# 1401800000001000  55610.0  79370.0  134980             1  1401800000001000
# 1401800000002000  55920.0  53230.0  109150             1  1401800000002000

# %%
# Count the number of Unique Values
parceldatavalues_2010_df_parcelcount_sum[['parid']].nunique()
# Out:
# parid    42146
# dtype: int64

# %%
parceldatavalues_2010_df_parcelcount_sum[['parid']].describe()
# Out:
#               parid
# count  4.214600e+04
# mean   1.643548e+16
# std    3.782676e+15
# min    1.401700e+15
# 25%    1.450151e+16
# 50%    1.660244e+16
# 75%    1.920103e+16
# max    2.360140e+16

# %% [markdown]
# ### Compare parcels with multiple counts to see if sum of appraised values is accurate
# The question is - do duplicate parcels have the same appraised values and therefore the appraised values should not be summed or if the appraised values need to be summed to provide accurate total value.
#
# 40,056 out of 42,146 parcels have 1 parcel id in the tax sheets. But 2,090 parcels have counts greater than 1.
# Four parcels are the the tax sheets 22 times.
#
# From exploring the data it appears that the duplicates should simply use the single value. In the cases explored the duplicate values are identical appraisal values across observations and across tax sheets.

# %%
pd.crosstab(index=parceldatavalues_2010_df_parcelcount_sum['parcel_count'], columns="count", margins=True, margins_name="Total")
# Out:
# col_0         count  Total
# parcel_count
# 1             40056  40056
# 2              1629   1629
# 3               236    236
# 4               104    104
# 5                37     37
# 6                24     24
# 7                 9      9
# 8                 7      7
# 9                 8      8
# 10                7      7
# 11                8      8
# 12                4      4
# 13                2      2
# 14                1      1
# 15                3      3
# 16                2      2
# 17                3      3
# 18                1      1
# 20                1      1
# 22                4      4
# Total         42146  42146

# %%
parceldatavalues_2010_df_parcelcount_sum.loc[parceldatavalues_2010_df_parcelcount_sum['parcel_count']>10]
# Out:
#                       APRBLDG     APRLAND    APRTOT  parcel_count  \
# PARID
# 9803300000001000    4872340.0   3888500.0   8760840            22
# 14200410007001000  15579820.0    579700.0  16159520            17
# 14200930001004000  20232520.0    963200.0  21195720            14
# 14200930001015000  21092400.0   1560000.0  22652400            15
# 14501500000012000  10659000.0   1407600.0  12066600            12
# 14501520005040000   3569280.0   2205060.0   5774340            11
# 15401820002001000  27019460.0    643450.0  27662910            17
# 15401840020003000   3546560.0    426240.0   3972800            16
# 15601300000009000   9572000.0  22429600.0  32001600            16
# 15903000000027000  12199800.0    669600.0  12869400            12
# 15903030003002006  13641540.0   2190760.0  15832300            11
# 15903130003020000  20365150.0   6968910.0  27334060            13
# 15903140008019000  13435840.0   1998480.0  15434320            11
# 16501630006016006  45009540.0   1672630.0  46682170            17
# 19100240022001000   1593460.0   1182720.0   2776180            11
# 19101110015001000  32873850.0   2172000.0  35045850            15
# 19200320004001000  45608400.0   5697000.0  51305400            20
# 19200330023013000   1930320.0    134280.0   2064600            12
# 19200910014001000  14158540.0    467060.0  14625600            11
# 19501510038001000  13830310.0   1139190.0  14969500            13
# 19501610014004000  23277760.0   2297680.0  25575440            22
# 19601310012016000  67468720.0   2045340.0  69514060            22
# 19601330014001000  40332600.0   1272300.0  41604900            15
# 20100200000021003   9262550.0    435270.0   9697820            11
# 20200300000001000  25301160.0   3011760.0  28312920            12
# 20300600000002000  43846200.0   3236940.0  47083140            18
# 20300720011002000   7091590.0    326700.0   7418290            11
# 20300720012001000  12833920.0    653400.0  13487320            22
# 20401800000014000   4270530.0   4168230.0   8438760            11
#
#                                parid
# PARID
# 9803300000001000    9803300000001000
# 14200410007001000  14200410007001000
# 14200930001004000  14200930001004000
# 14200930001015000  14200930001015000
# 14501500000012000  14501500000012000
# 14501520005040000  14501520005040000
# 15401820002001000  15401820002001000
# 15401840020003000  15401840020003000
# 15601300000009000  15601300000009000
# 15903000000027000  15903000000027000
# 15903030003002006  15903030003002006
# 15903130003020000  15903130003020000
# 15903140008019000  15903140008019000
# 16501630006016006  16501630006016006
# 19100240022001000  19100240022001000
# 19101110015001000  19101110015001000
# 19200320004001000  19200320004001000
# 19200330023013000  19200330023013000
# 19200910014001000  19200910014001000
# 19501510038001000  19501510038001000
# 19501610014004000  19501610014004000
# 19601310012016000  19601310012016000
# 19601330014001000  19601330014001000
# 20100200000021003  20100200000021003
# 20200300000001000  20200300000001000
# 20300600000002000  20300600000002000
# 20300720011002000  20300720011002000
# 20300720012001000  20300720012001000
# 20401800000014000  20401800000014000

# %%
parceldatavalues_2010_df[['PARID','ADRSTR','APRBLDG','APRLAND','APRTOT','OWN1']].loc[parceldatavalues_2010_df['PARID']==
                                                                                     20300720012001000]
# Out:
#                    PARID  ADRSTR   APRBLDG  APRLAND  APRTOT             OWN1
# 38570  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38571  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38572  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38573  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38574  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38575  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38576  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38577  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38578  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38579  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38580  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38581  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38582  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38583  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38584  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38585  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38586  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38587  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38588  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38589  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38590  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES
# 38591  20300720012001000  BRAMER  583360.0  29700.0  613060  GUS ENTERPRISES

# %%
parceldatavalues_2010_df[['PARID','ADRSTR','APRBLDG','APRLAND','APRTOT','OWN1']].loc[parceldatavalues_2010_df['PARID']==
                                                                                     19601310012016000]
# Out:
#                    PARID      ADRSTR    APRBLDG  APRLAND   APRTOT  \
# 35036  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35037  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35038  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35039  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35040  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35041  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35042  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35043  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35044  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35045  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35046  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35047  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35048  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35049  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35050  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35051  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35052  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35053  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35054  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35055  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35056  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
# 35057  19601310012016000  PO BOX 973  3066760.0  92970.0  3159730
#
#                      OWN1
# 35036  BIRD, CHARLES R TR
# 35037  BIRD, CHARLES R TR
# 35038  BIRD, CHARLES R TR
# 35039  BIRD, CHARLES R TR
# 35040  BIRD, CHARLES R TR
# 35041  BIRD, CHARLES R TR
# 35042  BIRD, CHARLES R TR
# 35043  BIRD, CHARLES R TR
# 35044  BIRD, CHARLES R TR
# 35045  BIRD, CHARLES R TR
# 35046  BIRD, CHARLES R TR
# 35047  BIRD, CHARLES R TR
# 35048  BIRD, CHARLES R TR
# 35049  BIRD, CHARLES R TR
# 35050  BIRD, CHARLES R TR
# 35051  BIRD, CHARLES R TR
# 35052  BIRD, CHARLES R TR
# 35053  BIRD, CHARLES R TR
# 35054  BIRD, CHARLES R TR
# 35055  BIRD, CHARLES R TR
# 35056  BIRD, CHARLES R TR
# 35057  BIRD, CHARLES R TR

# %%
parceldatavalues_2010_df[['PARID','ADRSTR','APRBLDG','APRLAND','APRTOT','OWN1']].loc[parceldatavalues_2010_df['PARID']==
                                                                                     15903030003002006]
# Out:
#                   PARID  ADRSTR    APRBLDG   APRLAND   APRTOT  \
# 1628  15903030003002006  GENEVA  1240140.0  199160.0  1439300
# 1629  15903030003002006  GENEVA  1240140.0  199160.0  1439300
# 1630  15903030003002006  GENEVA  1240140.0  199160.0  1439300
# 1631  15903030003002006  GENEVA  1240140.0  199160.0  1439300
# 1632  15903030003002006  GENEVA  1240140.0  199160.0  1439300
# 1633  15903030003002006  GENEVA  1240140.0  199160.0  1439300
# 1634  15903030003002006  GENEVA  1240140.0  199160.0  1439300
# 1635  15903030003002006  GENEVA  1240140.0  199160.0  1439300
# 1636  15903030003002006  GENEVA  1240140.0  199160.0  1439300
# 1637  15903030003002006  GENEVA  1240140.0  199160.0  1439300
# 1638  15903030003002006  GENEVA  1240140.0  199160.0  1439300
#
#                         OWN1
# 1628  BOX, DAVID JR & CARRIE
# 1629  BOX, DAVID JR & CARRIE
# 1630  BOX, DAVID JR & CARRIE
# 1631  BOX, DAVID JR & CARRIE
# 1632  BOX, DAVID JR & CARRIE
# 1633  BOX, DAVID JR & CARRIE
# 1634  BOX, DAVID JR & CARRIE
# 1635  BOX, DAVID JR & CARRIE
# 1636  BOX, DAVID JR & CARRIE
# 1637  BOX, DAVID JR & CARRIE
# 1638  BOX, DAVID JR & CARRIE

# %%
# Collapse Parcels By Parcel ID
parceldatavalues_2010_df_parceldata = parceldatavalues_2010_df[['PARID','CLASS','taxsheet']]
#if blank values are NaN first replace to ''
parceldatavalues_2010_df_parceldata = parceldatavalues_2010_df_parceldata.fillna('')
parceldatavalues_2010_df_parcelcount_unique = parceldatavalues_2010_df_parceldata.groupby(['PARID']).agg(lambda x: ''.join(x.unique()))
parceldatavalues_2010_df_parcelcount_unique.head()
# Out:
#                  CLASS   taxsheet
# PARID
# 1401700000002000     R   2010 Res
# 1401700000003000     R   2010 Res
# 1401700000004000     E  2010 Comm
# 1401800000001000     R   2010 Res
# 1401800000002000     R   2010 Res

# %%
pd.crosstab(parceldatavalues_2010_df_parcelcount_unique['CLASS'], parceldatavalues_2010_df_parcelcount_unique['taxsheet'],
            margins=True, margins_name="Total")
# Out:
# taxsheet  2010 Comm  2010 Comm2010 Res  2010 Res  Total
# CLASS
#                 756                  6      9532  10294
# A                 4                  0         6     10
# AR                0                  3         1      4
# C              2069                 20        50   2139
# CR                8                177         5    190
# E               209                 18       111    338
# EC                1                  1         0      2
# ER                0                  1         2      3
# R               124                 45     28989  29158
# RC                5                  3         0      8
# Total          3176                274     38696  42146

# %%
parceldatavalues_2010_df_parcelcount_unique.loc[parceldatavalues_2010_df_parcelcount_unique['CLASS']=="CR"]
# Out:
#                   CLASS           taxsheet
# PARID
# 2702600000001000     CR  2010 Comm2010 Res
# 3501500000006000     CR  2010 Comm2010 Res
# 3602300000019000     CR  2010 Comm2010 Res
# 3602420006008001     CR  2010 Comm2010 Res
# 3602420007001000     CR  2010 Comm2010 Res
# 3602420024002000     CR  2010 Comm2010 Res
# 3703500000009000     CR  2010 Comm2010 Res
# 7702600000003004     CR  2010 Comm2010 Res
# 7703500000027000     CR  2010 Comm2010 Res
# 7703640001001000     CR  2010 Comm2010 Res
# 7803400000012000     CR  2010 Comm2010 Res
# 7903100000014000     CR  2010 Comm2010 Res
# 8320540001002000     CR           2010 Res
# 8501530001008000     CR  2010 Comm2010 Res
# 8802800000014000     CR  2010 Comm2010 Res
# 8902900000009000     CR  2010 Comm2010 Res
# 9502100000003002     CR  2010 Comm2010 Res
# 9702500000018000     CR  2010 Comm2010 Res
# 9702600000002008     CR  2010 Comm2010 Res
# 9802700000005000     CR  2010 Comm2010 Res
# 9803400000003002     CR  2010 Comm2010 Res
# 9902900000006001     CR          2010 Comm
# 10803300000004000    CR  2010 Comm2010 Res
# 10903000000004000    CR  2010 Comm2010 Res
# 11320700000001000    CR  2010 Comm2010 Res
# 11702600000011000    CR  2010 Comm2010 Res
# 11903040002010000    CR  2010 Comm2010 Res
# 12200300000007000    CR  2010 Comm2010 Res
# 13100200000018000    CR  2010 Comm2010 Res
# 13702610002003000    CR  2010 Comm2010 Res
# ...                 ...                ...
# 20300710008004000    CR  2010 Comm2010 Res
# 20300720001002000    CR  2010 Comm2010 Res
# 20300720025006001    CR  2010 Comm2010 Res
# 20300740003002000    CR  2010 Comm2010 Res
# 20300740004012000    CR  2010 Comm2010 Res
# 20300810001001001    CR  2010 Comm2010 Res
# 20300810001009000    CR  2010 Comm2010 Res
# 20300820001001000    CR  2010 Comm2010 Res
# 20300820002048000    CR  2010 Comm2010 Res
# 20300830001036000    CR  2010 Comm2010 Res
# 20300840001003000    CR  2010 Comm2010 Res
# 20401720007016000    CR  2010 Comm2010 Res
# 20401800000032000    CR  2010 Comm2010 Res
# 20501500000014003    CR  2010 Comm2010 Res
# 20501600000003000    CR  2010 Comm2010 Res
# 20501600000013000    CR  2010 Comm2010 Res
# 20501600000028000    CR  2010 Comm2010 Res
# 20501620008016001    CR  2010 Comm2010 Res
# 21200440001010900    CR  2010 Comm2010 Res
# 21501500000005000    CR          2010 Comm
# 21501500000010000    CR  2010 Comm2010 Res
# 21501600000005000    CR  2010 Comm2010 Res
# 22300800000005000    CR  2010 Comm2010 Res
# 22501600000005000    CR  2010 Comm2010 Res
# 23200400000016000    CR  2010 Comm2010 Res
# 23200900000009006    CR  2010 Comm2010 Res
# 23300700000001000    CR  2010 Comm2010 Res
# 23300700000039000    CR  2010 Comm2010 Res
# 23300830002001000    CR  2010 Comm2010 Res
# 23300830017007000    CR  2010 Comm2010 Res
#
# [190 rows x 2 columns]

# %%
parceldatavalues_2010_df[['PARID','ADRSTR','APRBLDG','APRLAND','APRTOT','OWN1','taxsheet','CLASS']].loc[parceldatavalues_2010_df['PARID']==
                                                                                     23300830017007000]
# Out:
#                    PARID    ADRSTR  APRBLDG  APRLAND  APRTOT  \
# 4524   23300830017007000  CLARENCE  49590.0   3610.0   53200
# 40452  23300830017007000  CLARENCE  49590.0   3610.0   53200
#
#                              OWN1   taxsheet CLASS
# 4524   BLACK, BENJAMIN F & RUTH M  2010 Comm     C
# 40452  BLACK, BENJAMIN F & RUTH M   2010 Res     R

# %%
parceldatavalues_2010_df[['PARID','ADRSTR','APRBLDG','APRLAND','APRTOT','OWN1','taxsheet','CLASS']].loc[parceldatavalues_2010_df['PARID']==
                                                                                     20401800000032000]
# Out:
#                    PARID        ADRSTR   APRBLDG   APRLAND  APRTOT  \
# 4315   20401800000032000  PO BOX 25025  442480.0  316100.0  758580
# 39417  20401800000032000  PO BOX 25025  442480.0  316100.0  758580
#
#                                       OWN1   taxsheet CLASS
# 4315   STORAGE EQUITIES INC PS PARTNERS IV  2010 Comm     C
# 39417  STORAGE EQUITIES INC PS PARTNERS IV   2010 Res     R

# %%
# Group by moves the unique id to the index - make a new variable for merge
parceldatavalues_2010_df_parcelcount_unique['parid'] = parceldatavalues_2010_df_parcelcount_unique.index
parceldatavalues_2010_df_parcelcount_unique['classv2'] = parceldatavalues_2010_df_parcelcount_unique['CLASS']
parceldatavalues_2010_df_parcelcount_unique['taxsheetv2'] = parceldatavalues_2010_df_parcelcount_unique['taxsheet']
parceldatavalues_2010_df_parcelcount_unique.head()
# Out:
#                  CLASS   taxsheet             parid classv2 taxsheetv2
# PARID
# 1401700000002000     R   2010 Res  1401700000002000       R   2010 Res
# 1401700000003000     R   2010 Res  1401700000003000       R   2010 Res
# 1401700000004000     E  2010 Comm  1401700000004000       E  2010 Comm
# 1401800000001000     R   2010 Res  1401800000001000       R   2010 Res
# 1401800000002000     R   2010 Res  1401800000002000       R   2010 Res

# %% [markdown]
# ### One last check - Generate Min Max Appraisal Values

# %%
# Collapse Parcels By Parcel ID
parceldatavalues_2010_df_parcelcount = parceldatavalues_2010_df[['PARID','APRBLDG','APRLAND','APRTOT']]
parceldatavalues_2010_df_parcelcount['parcel_count'] = 1
parceldatavalues_2010_df_parcelcount_min = parceldatavalues_2010_df_parcelcount.groupby(['PARID']).min()
parceldatavalues_2010_df_parcelcount_max = parceldatavalues_2010_df_parcelcount.groupby(['PARID']).max()
parceldatavalues_2010_df_parcelcount_minmax = pd.merge(parceldatavalues_2010_df_parcelcount_min, 
                                                       parceldatavalues_2010_df_parcelcount_max,
                                                       left_on='PARID', right_on='PARID', how='left')
parceldatavalues_2010_df_parcelcount_minmax['diff_aprbldg'] = parceldatavalues_2010_df_parcelcount_minmax['APRBLDG_x'] - parceldatavalues_2010_df_parcelcount_minmax['APRBLDG_y']
parceldatavalues_2010_df_parcelcount_minmax['diff_aprbldg'].describe()
# Out:
# C:\Users\nathanael99\AppData\Local\Continuum\anaconda3\envs\pyincore20190618\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# count    42141.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
# Name: diff_aprbldg, dtype: float64

# %% [markdown]
# ### Based on the exploration duplicate parcels ids should be dropped

# %%
parceldatavalues_2010_df_nodup = parceldatavalues_2010_df.drop_duplicates(subset=['PARID'])
parceldatavalues_2010_df_nodup['PARID'].describe()
# Out:
# count    4.214600e+04
# mean     1.643548e+16
# std      3.782676e+15
# min      1.401700e+15
# 25%      1.450151e+16
# 50%      1.660244e+16
# 75%      1.920103e+16
# max      2.360140e+16
# Name: PARID, dtype: float64

# %%
parceldatavalues_2010_df_nodup['PARID'].nunique()
# Out:
# 42146

# %% [markdown]
# ### To keep track of parcel data merge in Tax Sheet and Parcel Count Information

# %%
parceldatavalues_2010_df_nodupv2 = pd.merge(parceldatavalues_2010_df_nodup, 
                                    parceldatavalues_2010_df_parcelcount_sum[['parid','parcel_count']], 
                                    left_on='PARID', right_on='parid', how='left')
parceldatavalues_2010_df_nodupv2 = pd.merge(parceldatavalues_2010_df_nodupv2, 
                                    parceldatavalues_2010_df_parcelcount_unique[['parid','classv2','taxsheetv2']], 
                                    left_on='PARID', right_on='parid', how='left')
# Drop duplicate columns for parid
dropcols = ['parid_x','parid_y']
cols = [col for col in parceldatavalues_2010_df_nodupv2 if col not in dropcols]
parceldatavalues_2010_df_nodupv2 = parceldatavalues_2010_df_nodupv2[cols]
parceldatavalues_2010_df_nodupv2.head()
# Out:
#    #   ACRES ADRDIR ADRDIR.1    ADRNO  ADRNO.1         ADRSTR       ADRSTR.1  \
# 0  1    2.48    NaN      NaN      NaN   5503.0            NaN          THORN
# 1  2  326.06    NaN      NaN  20654.0  20654.0  COUNTY RD 100  COUNTY RD 100
# 2  3  140.32    NaN      NaN   8378.0   8378.0          SUMAC          SUMAC
# 3  4    4.16    NaN      NaN  15515.0  15515.0          THORN          THORN
# 4  5    1.12    NaN      NaN      NaN      NaN     PO BOX 236            4TH
#
#     APRBLDG  APRLAND  ...             PARID  STATECODE STRUCTURE TAXYR YRBLT  \
# 0   10890.0  14880.0  ...  1401700000004000         MO     620.0  2010  1900
# 1   82940.0  84990.0  ...  2501500000002000         MO     354.0  2010  2006
# 2  112130.0  64840.0  ...  2702600000001000         MO     342.0  2010  2006
# 3  102950.0   9400.0  ...  3501500000006000         MO     342.0  2010  1987
# 4   24550.0   6480.0  ...  3601330001004000         MO     336.0  2010  1980
#
#       ZIP1   taxsheet  parcel_count  classv2         taxsheetv2
# 0  64748.0  2010 Comm             1        E          2010 Comm
# 1  64755.0  2010 Comm             2       AR  2010 Comm2010 Res
# 2  64755.0  2010 Comm             2       CR  2010 Comm2010 Res
# 3  64755.0  2010 Comm             2       CR  2010 Comm2010 Res
# 4  64755.0  2010 Comm             3        C          2010 Comm
#
# [5 rows x 25 columns]

# %%
pd.crosstab(parceldatavalues_2010_df_nodupv2['classv2'], parceldatavalues_2010_df_nodupv2['taxsheetv2'],
            margins=True, margins_name="Total")
# Out:
# taxsheetv2  2010 Comm  2010 Comm2010 Res  2010 Res  Total
# classv2
#                   756                  6      9532  10294
# A                   4                  0         6     10
# AR                  0                  3         1      4
# C                2069                 20        50   2139
# CR                  8                177         5    190
# E                 209                 18       111    338
# EC                  1                  1         0      2
# ER                  0                  1         2      3
# R                 124                 45     28989  29158
# RC                  5                  3         0      8
# Total            3176                274     38696  42146

# %% [markdown]
# ## Add Cleaned up Parcel Tax Data to Parcel GeoDataFrame

# %%
parceldata_gdf_dissolve['parid'] = parceldata_gdf_dissolve.index
parceldata_gdf_dissolve.head()
# Out:
#                                                             geometry  \
# PIN
# 01401700000001000  POLYGON ((-94.13699017271023 37.35055489878356...
# 01401700000002000  POLYGON ((-94.14188721000529 37.33973595930397...
# 01401700000003000  POLYGON ((-94.14613735909428 37.35070183976294...
# 01401700000004000  POLYGON ((-94.14660779875197 37.33704609240082...
# 01401800000001000  POLYGON ((-94.15538782377411 37.35084969271262...
#
#                                  PIN  Graphic_Ac  Legal_Ac  \
# PIN
# 01401700000001000  01401700000001000   159.58900    160.00
# 01401700000002000  01401700000002000   161.07700    158.22
# 01401700000003000  01401700000003000   323.00700    317.32
# 01401700000004000  01401700000004000     2.47968      2.48
# 01401800000001000  01401800000001000   313.29600    313.50
#
#                                    Address Notes Zoning  \
# PIN
# 01401700000001000  0  THORN & COUNTY RD 50  None   None
# 01401700000002000           5296  THORN RD  None   None
# 01401700000003000           5699  THORN RD  None   None
# 01401700000004000           5503  THORN RD  None   None
# 01401800000001000      20912  COUNTY RD 70  None   None
#
#                                         Own_Name  \
# PIN
# 01401700000001000  SEELA, RAYMOND E & FLORENCE A
# 01401700000002000     NEIDIGH, JOSEPH A & LISA L
# 01401700000003000       WILSON, SAM L & KRISTI L
# 01401700000004000    PLEASANT VIEW CEMETERY ASSN
# 01401800000001000  POTTS, LOREN A JR & GEORGIA H
#
#                                               Own_Addres    SHAPE_Leng  \
# PIN
# 01401700000001000  19483  COUNTY RD 50  ;JASPER;MO;64755  13159.744243
# 01401700000002000        5269  THORN RD ;JASPER;MO;64755  13194.656023
# 01401700000003000   1005  DALTON RD ;CEDAR VALE;KS;67024  15873.444758
# 01401700000004000             0    ;GOLDEN CITY;MO;64748   1333.926784
# 01401800000001000  20912  COUNTY RD 70  ;JASPER;MO;64755  15641.425320
#
#                      SHAPE_Area                                     rppnt4326  \
# PIN
# 01401700000001000  6.951680e+06  POINT (-94.13949023525831 37.34331162232674)
# 01401700000002000  7.016507e+06  POINT (-94.14408989691671 37.34343354130833)
# 01401700000003000  1.407020e+07  POINT (-94.15103837923394 37.34357968919036)
# 01401700000004000  1.080150e+05  POINT (-94.14644183959757 37.33666245802258)
# 01401800000001000  1.364726e+07  POINT (-94.16443045230865 37.34744841332255)
#
#                                                             prcl4326  \
# PIN
# 01401700000001000  POLYGON ((-94.13699017271023 37.35055489878356...
# 01401700000002000  POLYGON ((-94.14188721000529 37.33973595930397...
# 01401700000003000  POLYGON ((-94.14613735909428 37.35070183976294...
# 01401700000004000  POLYGON ((-94.14660779875197 37.33704609240082...
# 01401800000001000  POLYGON ((-94.15538782377411 37.35084969271262...
#
#                                parid
# PIN
# 01401700000001000  01401700000001000
# 01401700000002000  01401700000002000
# 01401700000003000  01401700000003000
# 01401700000004000  01401700000004000
# 01401800000001000  01401800000001000

# %%
parceldata_gdf_dissolve['parid'].describe()
# Out:
# count                 57235
# unique                57235
# top       07121100000006000
# freq                      1
# Name: parid, dtype: object

# %%
# Make Merge ID a string
parceldatavalues_2010_df_nodupv2['parid'] = parceldatavalues_2010_df_nodupv2['PARID'] .apply(lambda x : str((x)))
parceldatavalues_2010_df_nodupv2['parid'].describe()
# Out:
# count                 42146
# unique                42146
# top       14200420001012000
# freq                      1
# Name: parid, dtype: object

# %%
parceldatavalues_2010_df_nodupv2.head()
# Out:
#    #   ACRES ADRDIR ADRDIR.1    ADRNO  ADRNO.1         ADRSTR       ADRSTR.1  \
# 0  1    2.48    NaN      NaN      NaN   5503.0            NaN          THORN
# 1  2  326.06    NaN      NaN  20654.0  20654.0  COUNTY RD 100  COUNTY RD 100
# 2  3  140.32    NaN      NaN   8378.0   8378.0          SUMAC          SUMAC
# 3  4    4.16    NaN      NaN  15515.0  15515.0          THORN          THORN
# 4  5    1.12    NaN      NaN      NaN      NaN     PO BOX 236            4TH
#
#     APRBLDG  APRLAND  ...  STATECODE  STRUCTURE TAXYR YRBLT     ZIP1  \
# 0   10890.0  14880.0  ...         MO      620.0  2010  1900  64748.0
# 1   82940.0  84990.0  ...         MO      354.0  2010  2006  64755.0
# 2  112130.0  64840.0  ...         MO      342.0  2010  2006  64755.0
# 3  102950.0   9400.0  ...         MO      342.0  2010  1987  64755.0
# 4   24550.0   6480.0  ...         MO      336.0  2010  1980  64755.0
#
#     taxsheet parcel_count  classv2         taxsheetv2             parid
# 0  2010 Comm            1        E          2010 Comm  1401700000004000
# 1  2010 Comm            2       AR  2010 Comm2010 Res  2501500000002000
# 2  2010 Comm            2       CR  2010 Comm2010 Res  2702600000001000
# 3  2010 Comm            2       CR  2010 Comm2010 Res  3501500000006000
# 4  2010 Comm            3        C          2010 Comm  3601330001004000
#
# [5 rows x 26 columns]

# %%
# Merge Tax data with Parcel Shape Data
parceldata_gdf_dissolve_2010values = pd.merge(parceldata_gdf_dissolve, parceldatavalues_2010_df_nodupv2, 
                                              left_on='parid', right_on='parid', how='left')
parceldata_gdf_dissolve_2010values.head()
# Out:
#                                             geometry                PIN  \
# 0  POLYGON ((-94.13699017271023 37.35055489878356...  01401700000001000
# 1  POLYGON ((-94.14188721000529 37.33973595930397...  01401700000002000
# 2  POLYGON ((-94.14613735909428 37.35070183976294...  01401700000003000
# 3  POLYGON ((-94.14660779875197 37.33704609240082...  01401700000004000
# 4  POLYGON ((-94.15538782377411 37.35084969271262...  01401800000001000
#
#    Graphic_Ac  Legal_Ac                  Address Notes Zoning  \
# 0   159.58900    160.00  0  THORN & COUNTY RD 50  None   None
# 1   161.07700    158.22           5296  THORN RD  None   None
# 2   323.00700    317.32           5699  THORN RD  None   None
# 3     2.47968      2.48           5503  THORN RD  None   None
# 4   313.29600    313.50      20912  COUNTY RD 70  None   None
#
#                         Own_Name                             Own_Addres  \
# 0  SEELA, RAYMOND E & FLORENCE A  19483  COUNTY RD 50  ;JASPER;MO;64755
# 1     NEIDIGH, JOSEPH A & LISA L        5269  THORN RD ;JASPER;MO;64755
# 2       WILSON, SAM L & KRISTI L   1005  DALTON RD ;CEDAR VALE;KS;67024
# 3    PLEASANT VIEW CEMETERY ASSN             0    ;GOLDEN CITY;MO;64748
# 4  POTTS, LOREN A JR & GEORGIA H  20912  COUNTY RD 70  ;JASPER;MO;64755
#
#      SHAPE_Leng  ...  PARID STATECODE STRUCTURE TAXYR  YRBLT  ZIP1 taxsheet  \
# 0  13159.744243  ...    NaN       NaN       NaN   NaN    NaN   NaN      NaN
# 1  13194.656023  ...    NaN       NaN       NaN   NaN    NaN   NaN      NaN
# 2  15873.444758  ...    NaN       NaN       NaN   NaN    NaN   NaN      NaN
# 3   1333.926784  ...    NaN       NaN       NaN   NaN    NaN   NaN      NaN
# 4  15641.425320  ...    NaN       NaN       NaN   NaN    NaN   NaN      NaN
#
#   parcel_count  classv2  taxsheetv2
# 0          NaN      NaN         NaN
# 1          NaN      NaN         NaN
# 2          NaN      NaN         NaN
# 3          NaN      NaN         NaN
# 4          NaN      NaN         NaN
#
# [5 rows x 39 columns]

# %%
parceldata_gdf_dissolve_2010values['parid'].describe()
# Out:
# count                 57235
# unique                57235
# top       07121100000006000
# freq                      1
# Name: parid, dtype: object

# %%
pd.crosstab(parceldata_gdf_dissolve_2010values['classv2'], parceldata_gdf_dissolve_2010values['taxsheetv2'],margins=True, margins_name="Total")
# Out:
# taxsheetv2  2010 Comm  2010 Comm2010 Res  2010 Res  Total
# classv2
#                   700                  5      9406  10111
# A                   4                  0         3      7
# AR                  0                  2         0      2
# C                1886                 17        44   1947
# CR                  7                156         4    167
# E                 177                 17       101    295
# EC                  1                  1         0      2
# ER                  0                  0         1      1
# R                 119                 39     25138  25296
# RC                  5                  3         0      8
# Total            2899                240     34697  37836

# %%
pd.crosstab(parceldata_gdf_dissolve_2010values['Zoning'], parceldata_gdf_dissolve_2010values['classv2'],margins=True, margins_name="Total")
# Out:
# classv2        A    C  CR   E  EC  ER     R  RC  Total
# Zoning
# C1         90  0   91   1   8   0   0    51   0    241
# C1-PD      11  0   25   0   1   0   0     0   0     37
# C2         64  0  126   2   9   0   0    17   0    218
# C2-PD       6  0   10   0   0   0   0     1   0     17
# C3        132  0  199   5   6   0   0    23   2    367
# C3-PD       8  0    7   0   0   0   0     3   0     18
# CO         39  0   19   1   2   0   0    40   0    101
# CO-PD       7  0   23   0   0   0   0     0   0     30
# M1          2  0    1   0   0   0   0     0   0      3
# M1-PD      23  0    0   0   0   0   0    19   0     42
# M2        189  0  255   3   8   0   0    54   0    509
# M2-PD       2  0    6   0   0   0   0     0   0      8
# N/A         1  0    0   0   0   0   0     1   0      2
# R1       4125  1   29  10  29   0   1  6258   0  10453
# R1-PD      12  0    0   0   0   0   0    18   0     30
# R2       1373  0   12   0  19   0   0  1194   0   2598
# R2-PD      19  0    0   0   1   0   0    42   0     62
# R3        412  0    9   1   7   1   0   505   1    936
# R3-PD      22  0    0   1   2   0   0    47   0     72
# R4          4  0    0   0   0   0   0     8   0     12
# Total    6541  1  812  24  92   1   1  8281   3  15756

# %% [markdown]
# ## Read in Census Block Data
# Census Blocks provide an estimate of how many residiential address points (housing units) should be located in each block.

# %%
source_program = 'IN-CORE_1av2_Joplin_CleanBlockData_2019-07-10'
census_blocks_csv = source_program+"/"+source_program+"EPSG4269.csv"
census_blocks_df = pd.read_csv(census_blocks_csv)
census_blocks_df.head()
# Out:
#    Unnamed: 0  STATEFP10  COUNTYFP10  TRACTCE10  BLOCKCE        BLOCKID10  \
# 0           0         29          97      12100     1047  290970121001047
# 1           1         29          97      12100     1050  290970121001050
# 2           2         29          97      12100     1094  290970121001094
# 3           3         29          97      12100     1093  290970121001093
# 4           4         29          97      12100     1130  290970121001130
#
#   PARTFLG  HOUSING10  POP10  \
# 0       N          2      4
# 1       N          3      7
# 2       N          4     13
# 3       N          5      5
# 4       N          4      9
#
#                                             geometry  ...  \
# 0  POLYGON ((-94.13775 37.32550000000001, -94.138...  ...
# 1  POLYGON ((-94.137637 37.328675, -94.119315 37....  ...
# 2  POLYGON ((-94.214761 37.293836, -94.230751 37....  ...
# 3  POLYGON ((-94.197294 37.27723599999999, -94.19...  ...
# 4  POLYGON ((-94.151792 37.276275, -94.1519139999...  ...
#
#                                            blk104269       blockid apcount  \
# 0  POLYGON ((-94.13775 37.32550000000001, -94.138...  2.909701e+14     2.0
# 1  POLYGON ((-94.137637 37.328675, -94.119315 37....  2.909701e+14     3.0
# 2  POLYGON ((-94.214761 37.293836, -94.230751 37....  2.909701e+14     4.0
# 3  POLYGON ((-94.197294 37.27723599999999, -94.19...  2.909701e+14     5.0
# 4  POLYGON ((-94.151792 37.276275, -94.1519139999...  2.909701e+14     4.0
#
#    pop10  gqpop10  popdiff  PLCGEOID10  PLCNAME10  PUMGEOID10  \
# 0    4.0      0.0      0.0         NaN        NaN     2902800
# 1    7.0      0.0      0.0         NaN        NaN     2902800
# 2   13.0      0.0      0.0         NaN        NaN     2902800
# 3    5.0      0.0      0.0         NaN        NaN     2902800
# 4    9.0      0.0      0.0         NaN        NaN     2902800
#
#                        PUMNAME10
# 0  Jasper & Newton Counties PUMA
# 1  Jasper & Newton Counties PUMA
# 2  Jasper & Newton Counties PUMA
# 3  Jasper & Newton Counties PUMA
# 4  Jasper & Newton Counties PUMA
#
# [5 rows x 22 columns]

# %%
census_blocks_gdf = gpd.GeoDataFrame(census_blocks_df)
census_blocks_gdf.head()
# Out:
#    Unnamed: 0  STATEFP10  COUNTYFP10  TRACTCE10  BLOCKCE        BLOCKID10  \
# 0           0         29          97      12100     1047  290970121001047
# 1           1         29          97      12100     1050  290970121001050
# 2           2         29          97      12100     1094  290970121001094
# 3           3         29          97      12100     1093  290970121001093
# 4           4         29          97      12100     1130  290970121001130
#
#   PARTFLG  HOUSING10  POP10  \
# 0       N          2      4
# 1       N          3      7
# 2       N          4     13
# 3       N          5      5
# 4       N          4      9
#
#                                             geometry  ...  \
# 0  POLYGON ((-94.13775 37.32550000000001, -94.138...  ...
# 1  POLYGON ((-94.137637 37.328675, -94.119315 37....  ...
# 2  POLYGON ((-94.214761 37.293836, -94.230751 37....  ...
# 3  POLYGON ((-94.197294 37.27723599999999, -94.19...  ...
# 4  POLYGON ((-94.151792 37.276275, -94.1519139999...  ...
#
#                                            blk104269       blockid apcount  \
# 0  POLYGON ((-94.13775 37.32550000000001, -94.138...  2.909701e+14     2.0
# 1  POLYGON ((-94.137637 37.328675, -94.119315 37....  2.909701e+14     3.0
# 2  POLYGON ((-94.214761 37.293836, -94.230751 37....  2.909701e+14     4.0
# 3  POLYGON ((-94.197294 37.27723599999999, -94.19...  2.909701e+14     5.0
# 4  POLYGON ((-94.151792 37.276275, -94.1519139999...  2.909701e+14     4.0
#
#    pop10  gqpop10  popdiff  PLCGEOID10  PLCNAME10  PUMGEOID10  \
# 0    4.0      0.0      0.0         NaN        NaN     2902800
# 1    7.0      0.0      0.0         NaN        NaN     2902800
# 2   13.0      0.0      0.0         NaN        NaN     2902800
# 3    5.0      0.0      0.0         NaN        NaN     2902800
# 4    9.0      0.0      0.0         NaN        NaN     2902800
#
#                        PUMNAME10
# 0  Jasper & Newton Counties PUMA
# 1  Jasper & Newton Counties PUMA
# 2  Jasper & Newton Counties PUMA
# 3  Jasper & Newton Counties PUMA
# 4  Jasper & Newton Counties PUMA
#
# [5 rows x 22 columns]

# %%
census_blocks_gdf['geometry'].geom_type.describe()
# Out:
# count     0
# unique    0
# dtype: int64

# %%
# Use shapely.wkt loads to convert WKT to GeoSeries
from shapely.wkt import loads

census_blocks_gdf['geometry'] = census_blocks_gdf['geometry'].apply(lambda x: loads(x))
census_blocks_gdf['geometry'].geom_type.describe()
# Out:
# count        9621
# unique          2
# top       Polygon
# freq         9615
# dtype: object

# %%
census_blocks_gdf = census_blocks_gdf.set_geometry(census_blocks_gdf['geometry'])
census_blocks_gdf.crs = {'init':'epsg:4269'}
census_blocks_gdf.head()
# Out:
#    Unnamed: 0  STATEFP10  COUNTYFP10  TRACTCE10  BLOCKCE        BLOCKID10  \
# 0           0         29          97      12100     1047  290970121001047
# 1           1         29          97      12100     1050  290970121001050
# 2           2         29          97      12100     1094  290970121001094
# 3           3         29          97      12100     1093  290970121001093
# 4           4         29          97      12100     1130  290970121001130
#
#   PARTFLG  HOUSING10  POP10  \
# 0       N          2      4
# 1       N          3      7
# 2       N          4     13
# 3       N          5      5
# 4       N          4      9
#
#                                             geometry  ...  \
# 0  POLYGON ((-94.13775 37.32550000000001, -94.138...  ...
# 1  POLYGON ((-94.137637 37.328675, -94.119315 37....  ...
# 2  POLYGON ((-94.214761 37.293836, -94.230751 37....  ...
# 3  POLYGON ((-94.197294 37.27723599999999, -94.19...  ...
# 4  POLYGON ((-94.151792 37.276275, -94.1519139999...  ...
#
#                                            blk104269       blockid apcount  \
# 0  POLYGON ((-94.13775 37.32550000000001, -94.138...  2.909701e+14     2.0
# 1  POLYGON ((-94.137637 37.328675, -94.119315 37....  2.909701e+14     3.0
# 2  POLYGON ((-94.214761 37.293836, -94.230751 37....  2.909701e+14     4.0
# 3  POLYGON ((-94.197294 37.27723599999999, -94.19...  2.909701e+14     5.0
# 4  POLYGON ((-94.151792 37.276275, -94.1519139999...  2.909701e+14     4.0
#
#    pop10  gqpop10  popdiff  PLCGEOID10  PLCNAME10  PUMGEOID10  \
# 0    4.0      0.0      0.0         NaN        NaN     2902800
# 1    7.0      0.0      0.0         NaN        NaN     2902800
# 2   13.0      0.0      0.0         NaN        NaN     2902800
# 3    5.0      0.0      0.0         NaN        NaN     2902800
# 4    9.0      0.0      0.0         NaN        NaN     2902800
#
#                        PUMNAME10
# 0  Jasper & Newton Counties PUMA
# 1  Jasper & Newton Counties PUMA
# 2  Jasper & Newton Counties PUMA
# 3  Jasper & Newton Counties PUMA
# 4  Jasper & Newton Counties PUMA
#
# [5 rows x 22 columns]

# %%
# Convert Census Block CRS to Buildings CRS
census_blocks_gdf = census_blocks_gdf.to_crs({'init': 'epsg:4326'})
census_blocks_gdf.crs
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# ### Select Blocks inside Parcel Boundary

# %%
census_blocks_gdf['BLOCKID10'].describe()
# Out:
# count    9.621000e+03
# mean     2.911818e+14
# std      2.383822e+11
# min      2.909701e+14
# 25%      2.909701e+14
# 50%      2.909701e+14
# 75%      2.914502e+14
# max      2.914502e+14
# Name: BLOCKID10, dtype: float64

# %%
# Find the bounds of the Census Block File
# Add Small Buffer for blocks on the edges
buffer = 0.001
minx = parceldata_gdf_dissolve_2010values.bounds.minx.min() + buffer
miny = parceldata_gdf_dissolve_2010values.bounds.miny.min() + buffer
maxx = parceldata_gdf_dissolve_2010values.bounds.maxx.max() + buffer
maxy = parceldata_gdf_dissolve_2010values.bounds.maxy.max() + buffer
parceldata_gdf_dissolve_2010values_bounds = [minx, miny, maxx, maxy]
parceldata_gdf_dissolve_2010values_bounds
# Out:
# [-94.617280153866, 37.04921672450786, -94.05142215228076, 37.36517424596878]

# %%
# Select Blocks within Bounds of Study Area
# build the r-tree index - for blocks
sindex_census_blocks_gdf = census_blocks_gdf.sindex
possible_matches_index = list(sindex_census_blocks_gdf.intersection(parceldata_gdf_dissolve_2010values_bounds))
census_blocks_parcels_gdf = census_blocks_gdf.iloc[possible_matches_index]
census_blocks_parcels_gdf['BLOCKID10'].describe()
# Out:
# count    5.615000e+03
# mean     2.909906e+14
# std      9.711969e+10
# min      2.909701e+14
# 25%      2.909701e+14
# 50%      2.909701e+14
# 75%      2.909701e+14
# max      2.914502e+14
# Name: BLOCKID10, dtype: float64

# %% [markdown]
# ### Spatial JoinBlock Information to Parcels

# %%
# Confirm Count of Unique ID in layer to which data will be added
parceldata_gdf_dissolve_2010values['parid'].describe()
# Out:
# count                 57235
# unique                57235
# top       07121100000006000
# freq                      1
# Name: parid, dtype: object

# %%
# build the r-tree index - Using Representative Point
parceldata_gdf_dissolve_2010values.loc[parceldata_gdf_dissolve_2010values.index,'geometry'] = parceldata_gdf_dissolve_2010values['rppnt4326']
sindex_parceldata_gdf_dissolve_2010values = parceldata_gdf_dissolve_2010values.sindex
sindex_parceldata_gdf_dissolve_2010values

# %%
# find the points that intersect with each subpolygon and add ID to Point
for index, block in census_blocks_parcels_gdf.iterrows():
    if index%100==0:
        print(index)
        
    # find approximate matches with r-tree, then precise matches from those approximate ones
    possible_matches_index = list(sindex_parceldata_gdf_dissolve_2010values.intersection(block['geometry'].bounds))
    possible_matches = parceldata_gdf_dissolve_2010values.iloc[possible_matches_index]
    precise_matches = possible_matches[possible_matches.intersects(block['geometry'])]
    parceldata_gdf_dissolve_2010values.loc[precise_matches.index,'BLOCKID10'] = block['BLOCKID10']
    parceldata_gdf_dissolve_2010values.loc[precise_matches.index,'STATEFP10'] = block['STATEFP10']
    parceldata_gdf_dissolve_2010values.loc[precise_matches.index,'COUNTYFP10'] = block['COUNTYFP10']
    parceldata_gdf_dissolve_2010values.loc[precise_matches.index,'TRACTCE10'] = block['TRACTCE10']
    parceldata_gdf_dissolve_2010values.loc[precise_matches.index,'PUMGEOID10'] = block['PUMGEOID10']
    parceldata_gdf_dissolve_2010values.loc[precise_matches.index,'PUMNAME10'] = block['PUMNAME10']
    parceldata_gdf_dissolve_2010values.loc[precise_matches.index,'PLCGEOID10'] = block['PLCGEOID10']
    parceldata_gdf_dissolve_2010values.loc[precise_matches.index,'PLCNAME10'] = block['PLCNAME10']
# Out:
# 3800
# 0
# 600
# 2400
# 2800
# 3200
# 4400
# 1700
# 4500
# 400
# 3100
# 800
# 4600
# 1800
# 200
# 4300
# 100
# 900
# 700
# 1200
# 5200
# 1000
# 1900
# 3700
# 5000
# 500
# 3600
# 3300
# 1300
# 3900
# 5300
# 4000
# 2000
# 4700
# 2200
# 2900
# 2700
# 1600
# 1500
# 2100
# 3500
# 4800
# 2600
# 4100
# 300
# 5100
# 4200
# 3000
# 1100
# 4900
# 1400
# 3400
# 2500
# 7900
# 9500
# 2300
# 9200

# %%
# Confirm Count of Unique ID in layer to which data will be added
parceldata_gdf_dissolve_2010values['parid'].describe()
# Out:
# count                 57235
# unique                57235
# top       07121100000006000
# freq                      1
# Name: parid, dtype: object

# %%
# Switch Block Geography back to polygons
parceldata_gdf_dissolve_2010values.loc[parceldata_gdf_dissolve_2010values.index,'geometry'] = parceldata_gdf_dissolve_2010values['prcl4326']
parceldata_gdf_dissolve_2010values.head()
# Out:
#                                             geometry                PIN  \
# 0  POLYGON ((-94.13699017271023 37.35055489878356...  01401700000001000
# 1  POLYGON ((-94.14188721000529 37.33973595930397...  01401700000002000
# 2  POLYGON ((-94.14613735909428 37.35070183976294...  01401700000003000
# 3  POLYGON ((-94.14660779875197 37.33704609240082...  01401700000004000
# 4  POLYGON ((-94.15538782377411 37.35084969271262...  01401800000001000
#
#    Graphic_Ac  Legal_Ac                  Address Notes Zoning  \
# 0   159.58900    160.00  0  THORN & COUNTY RD 50  None   None
# 1   161.07700    158.22           5296  THORN RD  None   None
# 2   323.00700    317.32           5699  THORN RD  None   None
# 3     2.47968      2.48           5503  THORN RD  None   None
# 4   313.29600    313.50      20912  COUNTY RD 70  None   None
#
#                         Own_Name                             Own_Addres  \
# 0  SEELA, RAYMOND E & FLORENCE A  19483  COUNTY RD 50  ;JASPER;MO;64755
# 1     NEIDIGH, JOSEPH A & LISA L        5269  THORN RD ;JASPER;MO;64755
# 2       WILSON, SAM L & KRISTI L   1005  DALTON RD ;CEDAR VALE;KS;67024
# 3    PLEASANT VIEW CEMETERY ASSN             0    ;GOLDEN CITY;MO;64748
# 4  POTTS, LOREN A JR & GEORGIA H  20912  COUNTY RD 70  ;JASPER;MO;64755
#
#      SHAPE_Leng  ...  classv2 taxsheetv2     BLOCKID10 STATEFP10  COUNTYFP10  \
# 0  13159.744243  ...      NaN        NaN  2.909701e+14      29.0        97.0
# 1  13194.656023  ...      NaN        NaN  2.909701e+14      29.0        97.0
# 2  15873.444758  ...      NaN        NaN  2.909701e+14      29.0        97.0
# 3   1333.926784  ...      NaN        NaN  2.909701e+14      29.0        97.0
# 4  15641.425320  ...      NaN        NaN  2.909701e+14      29.0        97.0
#
#    TRACTCE10 PUMGEOID10                      PUMNAME10  PLCGEOID10  PLCNAME10
# 0    12100.0  2902800.0  Jasper & Newton Counties PUMA         NaN        NaN
# 1    12100.0  2902800.0  Jasper & Newton Counties PUMA         NaN        NaN
# 2    12100.0  2902800.0  Jasper & Newton Counties PUMA         NaN        NaN
# 3    12100.0  2902800.0  Jasper & Newton Counties PUMA         NaN        NaN
# 4    12100.0  2902800.0  Jasper & Newton Counties PUMA         NaN        NaN
#
# [5 rows x 47 columns]

# %%
# Look at One Place plot the intersections and the city
place_gdf_map = fm.Map(location=[(miny+maxy)/2,(minx+maxx)/2], zoom_start=10)
joplin_blocks_gdf = census_blocks_gdf[census_blocks_gdf['PLCNAME10']=='Joplin']
joplin_parcels_gdf = parceldata_gdf_dissolve_2010values[parceldata_gdf_dissolve_2010values['PLCNAME10']=='Joplin']
blockstyle_function = lambda x: {'color':'green','fillColor': 'transparent' }

fm.GeoJson(joplin_blocks_gdf['geometry'],name='Census Blocks',style_function=blockstyle_function).add_to(place_gdf_map)
fm.GeoJson(joplin_parcels_gdf['geometry'],name='Parcels').add_to(place_gdf_map)
fm.LayerControl().add_to(place_gdf_map)
place_gdf_map.save(programname+'/'+programname+'joplin_parcels_blocks.html')
# Error Displaying Map display(neosho_place_gdf_map)

# %% [markdown]
# ## How many parcels do not have blockids?

# %%
parceldata_gdf_dissolve_2010values.loc[parceldata_gdf_dissolve_2010values['BLOCKID10'].isnull()]
# Out:
#                                                 geometry                PIN  \
# 1326   POLYGON ((-94.60737629192255 37.3640126364568,...  05421800000001000
# 34979  POLYGON ((-94.61762151360274 37.14196682824367...  17502200000001001
# 34980  POLYGON ((-94.61776285811932 37.13833241481854...  17502240001001000
#
#        Graphic_Ac  Legal_Ac               Address                     Notes  \
# 1326     15.42640      0.00                  None  EMPIRE DISTRICT ELECTRIC
# 34979     6.11827      7.30  5700  STATE LINE AVE                      None
# 34980     3.91112      2.37                     0                      None
#
#       Zoning                  Own_Name                            Own_Addres  \
# 1326    None  EMPIRE DISTRICT ELECTRIC                                  None
# 34979   None     SCHROEDER, RALPH F TR       3609 E 20TH ST ;JOPLIN;MO;64801
# 34980   None     SCHROEDER, RALPH F TR  5700  STATE LINE RD ;JOPLIN;MO;64804
#
#          SHAPE_Leng  ...  classv2 taxsheetv2 BLOCKID10 STATEFP10  COUNTYFP10  \
# 1326   13972.212999  ...      NaN        NaN       NaN       NaN         NaN
# 34979   4507.231749  ...        R   2010 Res       NaN       NaN         NaN
# 34980   5425.919356  ...      NaN        NaN       NaN       NaN         NaN
#
#        TRACTCE10 PUMGEOID10 PUMNAME10  PLCGEOID10  PLCNAME10
# 1326         NaN        NaN       NaN         NaN        NaN
# 34979        NaN        NaN       NaN         NaN        NaN
# 34980        NaN        NaN       NaN         NaN        NaN
#
# [3 rows x 47 columns]

# %% [markdown]
# Parcels without Block IDS appear to be sliver polygons along the edge of the county line. Probably due to a mismatch between parcel polygons and block polygons.

# %% [markdown]
# ## How many blocks do not have parcels?

# %%
# Collapse Blocks By Place Name and Count Blocks 
parceldata_gdf_dissolve_2010values_parcelcount = parceldata_gdf_dissolve_2010values[['BLOCKID10']]
parceldata_gdf_dissolve_2010values_parcelcount['bldgcount_parcel_sum'] = 1
parceldata_gdf_dissolve_2010values_parcelcount_sum = parceldata_gdf_dissolve_2010values_parcelcount.groupby(['BLOCKID10']).sum()
parceldata_gdf_dissolve_2010values_parcelcount_sum['bldgcount_parcel_sum'].describe()
# Out:
# C:\Users\nathanael99\AppData\Local\Continuum\anaconda3\envs\pyincore20190618\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# count    4509.000000
# mean       12.692837
# std        17.904977
# min         1.000000
# 25%         5.000000
# 50%         9.000000
# 75%        15.000000
# max       448.000000
# Name: parcel_count, dtype: float64

# %%
# Add Block Count to Place Data
census_blocks_gdf_checkparcelcount = pd.merge(census_blocks_gdf, parceldata_gdf_dissolve_2010values_parcelcount_sum,
                                  left_on='BLOCKID10', right_on='BLOCKID10', how='left')
census_blocks_gdf_checkparcelcount.loc[(census_blocks_gdf_checkparcelcount['parcel_count'].isnull()) & 
                                      (census_blocks_gdf_checkparcelcount['COUNTYFP10'] == 97) &
                                      (census_blocks_gdf_checkparcelcount['HOUSING10'] > 0) & 
                                      (census_blocks_gdf_checkparcelcount['PLCNAME10'] == 'Joplin')].sort_values(by=['HOUSING10'])
# Out:
#       Unnamed: 0  STATEFP10  COUNTYFP10  TRACTCE10  BLOCKCE        BLOCKID10  \
# 356          356         29          97      10200     2009  290970102002009
# 665          665         29          97      11900     3034  290970119003034
# 1718        1718         29          97      10200     2032  290970102002032
# 2701        2701         29          97      10400     3046  290970104003046
# 3957        3957         29          97      10900     3002  290970109003002
# 4014        4014         29          97      10400     3050  290970104003050
# 1404        1404         29          97      11000     5053  290970110005053
# 2365        2365         29          97      11900     1017  290970119001017
# 3476        3476         29          97      11900     1018  290970119001018
# 4476        4476         29          97      11000     5057  290970110005057
# 3666        3666         29          97      10500     4013  290970105004013
# 3175        3175         29          97      11000     5055  290970110005055
# 1025        1025         29          97      11900     1014  290970119001014
# 944          944         29          97      10800     3036  290970108003036
# 434          434         29          97      10400     1006  290970104001006
#
#      PARTFLG  HOUSING10  POP10  \
# 356        N          1      3
# 665        N          1      2
# 1718       N          1      2
# 2701       N          1      2
# 3957       N          1      3
# 4014       N          1      2
# 1404       N          2      2
# 2365       N          2      4
# 3476       N          2      5
# 4476       N          2      4
# 3666       N          3      0
# 3175       N          6      3
# 1025       N          7     17
# 944        N         18     20
# 434        N         97    209
#
#                                                geometry  ...       blockid  \
# 356   POLYGON ((-94.50909899999999 37.113606, -94.50...  ...  2.909701e+14
# 665   POLYGON ((-94.41245499999999 37.068743, -94.41...  ...  2.909701e+14
# 1718  POLYGON ((-94.508617 37.113221, -94.508611 37....  ...  2.909701e+14
# 2701  POLYGON ((-94.44092499999999 37.055165, -94.44...  ...  2.909701e+14
# 3957  POLYGON ((-94.54062599999999 37.084461, -94.54...  ...  2.909701e+14
# 4014  POLYGON ((-94.44053699999999 37.05513, -94.439...  ...  2.909701e+14
# 1404  POLYGON ((-94.53138899999999 37.077306, -94.52...  ...  2.909701e+14
# 2365  POLYGON ((-94.432965 37.098214, -94.4322339999...  ...  2.909701e+14
# 3476  POLYGON ((-94.433638 37.097731, -94.433593 37....  ...  2.909701e+14
# 4476  POLYGON ((-94.52174199999999 37.077092, -94.52...  ...  2.909701e+14
# 3666  POLYGON ((-94.482513 37.064991, -94.4817769999...  ...  2.909701e+14
# 3175  POLYGON ((-94.52368 37.077139, -94.522875 37.0...  ...  2.909701e+14
# 1025  POLYGON ((-94.43153799999999 37.098228, -94.43...  ...  2.909701e+14
# 944   POLYGON ((-94.520178 37.063253, -94.520595 37....  ...  2.909701e+14
# 434   POLYGON ((-94.468147 37.089441, -94.4681169999...  ...  2.909701e+14
#
#      apcount  pop10  gqpop10  popdiff  PLCGEOID10  PLCNAME10  PUMGEOID10  \
# 356      1.0    3.0      0.0      0.0   2937592.0     Joplin     2902800
# 665      1.0    2.0      0.0      0.0   2937592.0     Joplin     2902800
# 1718     1.0    2.0      0.0      0.0   2937592.0     Joplin     2902800
# 2701     1.0    2.0      0.0      0.0   2937592.0     Joplin     2902800
# 3957     1.0    3.0      0.0      0.0   2937592.0     Joplin     2902800
# 4014     1.0    2.0      0.0      0.0   2937592.0     Joplin     2902800
# 1404     2.0    2.0      0.0      0.0   2937592.0     Joplin     2902800
# 2365     2.0    4.0      0.0      0.0   2937592.0     Joplin     2902800
# 3476     2.0    5.0      0.0      0.0   2937592.0     Joplin     2902800
# 4476     2.0    4.0      0.0      0.0   2937592.0     Joplin     2902800
# 3666     3.0    0.0      0.0      0.0   2937592.0     Joplin     2902800
# 3175     6.0    3.0      0.0      0.0   2937592.0     Joplin     2902800
# 1025     7.0   17.0      0.0      0.0   2937592.0     Joplin     2902800
# 944     18.0   20.0      0.0      0.0   2937592.0     Joplin     2902800
# 434     98.0  209.0    116.0      0.0   2937592.0     Joplin     2902800
#
#                           PUMNAME10 parcel_count
# 356   Jasper & Newton Counties PUMA          NaN
# 665   Jasper & Newton Counties PUMA          NaN
# 1718  Jasper & Newton Counties PUMA          NaN
# 2701  Jasper & Newton Counties PUMA          NaN
# 3957  Jasper & Newton Counties PUMA          NaN
# 4014  Jasper & Newton Counties PUMA          NaN
# 1404  Jasper & Newton Counties PUMA          NaN
# 2365  Jasper & Newton Counties PUMA          NaN
# 3476  Jasper & Newton Counties PUMA          NaN
# 4476  Jasper & Newton Counties PUMA          NaN
# 3666  Jasper & Newton Counties PUMA          NaN
# 3175  Jasper & Newton Counties PUMA          NaN
# 1025  Jasper & Newton Counties PUMA          NaN
# 944   Jasper & Newton Counties PUMA          NaN
# 434   Jasper & Newton Counties PUMA          NaN
#
# [15 rows x 23 columns]

# %% [markdown]
# #### Block 290970104001006
# The block is much smaller than the parcel. However when the buildings are assigned to the blocks and the parcel indidividually this block will have parcel data.
#
# #### Block 290970108003036
# Also a block that is smaller than the parcel. The Parcel is in 2 different blocks. The parcel does have 13 buildings, 6 in block 290970108003036 and 6 in block 290970108003024. The parcel has the address 605 W 25TH ST, which is in the path of the tornado. The zoning is R3 which would fit with the housing unit count of 18 (6 buildings with 3 units each)
#
#
# #### Block 290970119001014
# This is an interesting block. The parcels are long and most of the parcel is in a different block. But the street side of the parcel is in block 290970119001014. The neighboring block 290970119001013 will be assigned the parcels. In this case the block boundaries and parcel boundaries do not match well. The block layout follows the roads but the parcels do not follow the roads.

# %%
cols = [col for col in parceldata_gdf_dissolve_2010values]
cols
# Out:
# ['geometry',
#  'PIN',
#  'Graphic_Ac',
#  'Legal_Ac',
#  'Address',
#  'Notes',
#  'Zoning',
#  'Own_Name',
#  'Own_Addres',
#  'SHAPE_Leng',
#  'SHAPE_Area',
#  'rppnt4326',
#  'prcl4326',
#  'parid',
#  '#',
#  'ACRES',
#  'ADRDIR',
#  'ADRDIR.1',
#  'ADRNO',
#  'ADRNO.1',
#  'ADRSTR',
#  'ADRSTR.1',
#  'APRBLDG',
#  'APRLAND',
#  'APRTOT',
#  'CARD',
#  'CITYNAME',
#  'CLASS',
#  'OWN1',
#  'PARID',
#  'STATECODE',
#  'STRUCTURE',
#  'TAXYR',
#  'YRBLT',
#  'ZIP1',
#  'taxsheet',
#  'parcel_count',
#  'classv2',
#  'taxsheetv2',
#  'BLOCKID10',
#  'STATEFP10',
#  'COUNTYFP10',
#  'TRACTCE10',
#  'PUMGEOID10',
#  'PUMNAME10',
#  'PLCGEOID10',
#  'PLCNAME10']

# %%
# Move Primary Key Column to first Column
cols = ['parid']  + [col for col in parceldata_gdf_dissolve_2010values if col != 'parid']
parceldata_gdf_dissolve_2010values = parceldata_gdf_dissolve_2010values[cols]

# remove redudant columns
redudant_columns = ['PIN_x','#','PIN_y','ADRDIR.1','ADRNO.1','ADRSTR.1','PIN','PARID']
cols = [col for col in parceldata_gdf_dissolve_2010values if col not in redudant_columns]
parceldata_gdf_dissolve_2010values = parceldata_gdf_dissolve_2010values[cols]

cols = [col for col in parceldata_gdf_dissolve_2010values]
cols
# Out:
# ['parid',
#  'geometry',
#  'PIN',
#  'Graphic_Ac',
#  'Legal_Ac',
#  'Address',
#  'Notes',
#  'Zoning',
#  'Own_Name',
#  'Own_Addres',
#  'SHAPE_Leng',
#  'SHAPE_Area',
#  'rppnt4326',
#  'prcl4326',
#  'ACRES',
#  'ADRDIR',
#  'ADRNO',
#  'ADRSTR',
#  'APRBLDG',
#  'APRLAND',
#  'APRTOT',
#  'CARD',
#  'CITYNAME',
#  'CLASS',
#  'OWN1',
#  'PARID',
#  'STATECODE',
#  'STRUCTURE',
#  'TAXYR',
#  'YRBLT',
#  'ZIP1',
#  'taxsheet',
#  'parcel_count',
#  'classv2',
#  'taxsheetv2',
#  'BLOCKID10',
#  'STATEFP10',
#  'COUNTYFP10',
#  'TRACTCE10',
#  'PUMGEOID10',
#  'PUMNAME10',
#  'PLCGEOID10',
#  'PLCNAME10']

# %%
# Make parid a string by adding letter the front
parceldata_gdf_dissolve_2010values['parid'] = parceldata_gdf_dissolve_2010values['parid'].apply(lambda x : "P"+str(x))
parceldata_gdf_dissolve_2010values['parid'].head()
# Out:
# 0    P01401700000001000
# 1    P01401700000002000
# 2    P01401700000003000
# 3    P01401700000004000
# 4    P01401800000001000
# Name: parid, dtype: object

# %%
# Save Work at this point as CSV
savefile = sys.path[0]+"/"+programname+"/"+programname+"_EPSG4326.csv"
parceldata_gdf_dissolve_2010values.to_csv(savefile)
